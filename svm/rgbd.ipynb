# %%
import jupyros as jr

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
import rosbag
import rospy

from cv_bridge import CvBridge, CvBridgeError
from geometry_msgs.msg import TransformStamped
from sensor_msgs.msg import Image
from __future__ import print_function

# %%
from sklearn.cluster import KMeans

# %%
# %matplotlib inline

# %% [markdown]
# ### get an image
# from publisher

# %%
rospy.init_node('bin_picking')
img = None
while not rospy.Time.now():
    pass

# %%
def callback(data):
    img = bridge.imgmsg_to_cv2(data, "bgr8")
    print(img)
    #cv2.imshow(img)

# %%
jr.subscribe('/head_camera/rgb/image_raw', Image, callback)
#sub = rospy.Subscriber('/head_camera/rgb/image_raw', Image, callback)
bridge = CvBridge()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-491d352c132e> in <module>()
# ----> 1 jr.subscribe('/head_camera/rgb/image_raw', Image, callback)
#       2 #sub = rospy.Subscriber('/head_camera/rgb/image_raw', Image, callback)
#       3 bridge = CvBridge()
#
# /home/neil/.local/lib/python2.7/site-packages/jupyros/pubsub.pyc in subscribe(topic, msg_type, callback)
#      48
#      49     if subscriber_registry.get(topic):
# ---> 50         raise Error("Already registerd...")
#      51
#      52     out = widgets.Output(layout={'border': '1px solid gray'})
#
# NameError: global name 'Error' is not defined

# %%
while not rospy.is_shutdown():
    rospy.spin()

# %% [markdown]
# ### get an image
# from bag

# %%
bag = rosbag.Bag('../data/new_bin_with_screws.bag', "r")
bridge = CvBridge()

# %%
for _, msg, t in bag.read_messages(topics=['/head_camera/rgb/image_raw']):
    frame = bridge.imgmsg_to_cv2(msg, desired_encoding="passthrough")

# %%
plt.imshow(frame)

# %%
ALPHA = 1.5
BETA = 0
